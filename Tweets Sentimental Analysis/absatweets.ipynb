# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
import nltk
import warnings
# %matplotlib inline

warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', 100)
df = pd.read_csv('absatweets.csv', header = 0, error_bad_lines=False)
data = df[["id","extract","sentiment"]]
df.head(100)
# Out:
# b'Skipping line 11798: expected 41 fields, saw 48\nSkipping line 12162: expected 41 fields, saw 48\nSkipping line 12235: expected 41 fields, saw 48\nSkipping line 13081: expected 41 fields, saw 48\nSkipping line 13853: expected 41 fields, saw 48\nSkipping line 14590: expected 41 fields, saw 48\nSkipping line 15519: expected 41 fields, saw 48\nSkipping line 15564: expected 41 fields, saw 48\nSkipping line 15622: expected 41 fields, saw 48\n'
# b'Skipping line 16925: expected 41 fields, saw 48\nSkipping line 17897: expected 41 fields, saw 48\nSkipping line 18648: expected 41 fields, saw 48\nSkipping line 19129: expected 41 fields, saw 48\nSkipping line 20124: expected 41 fields, saw 48\nSkipping line 20334: expected 41 fields, saw 48\nSkipping line 20718: expected 41 fields, saw 48\nSkipping line 21059: expected 41 fields, saw 48\nSkipping line 21226: expected 41 fields, saw 48\nSkipping line 21858: expected 41 fields, saw 48\nSkipping line 22057: expected 41 fields, saw 48\nSkipping line 22058: expected 41 fields, saw 48\nSkipping line 22296: expected 41 fields, saw 48\nSkipping line 22509: expected 41 fields, saw 48\nSkipping line 22522: expected 41 fields, saw 48\nSkipping line 22545: expected 41 fields, saw 48\nSkipping line 22558: expected 41 fields, saw 48\nSkipping line 22559: expected 41 fields, saw 48\nSkipping line 22860: expected 41 fields, saw 48\nSkipping line 22875: expected 41 fields, saw 48\nSkipping line 22970: expected 41 fields, saw 48\nSkipping line 23015: expected 41 fields, saw 48\nSkipping line 23330: expected 41 fields, saw 48\nSkipping line 23347: expected 41 fields, saw 48\nSkipping line 23353: expected 41 fields, saw 48\nSkipping line 23445: expected 41 fields, saw 48\nSkipping line 23499: expected 41 fields, saw 48\nSkipping line 23837: expected 41 fields, saw 48\nSkipping line 23847: expected 41 fields, saw 48\nSkipping line 24168: expected 41 fields, saw 48\nSkipping line 24172: expected 41 fields, saw 48\nSkipping line 24183: expected 41 fields, saw 48\nSkipping line 24355: expected 41 fields, saw 48\nSkipping line 24376: expected 41 fields, saw 48\nSkipping line 24854: expected 41 fields, saw 48\nSkipping line 26501: expected 41 fields, saw 48\nSkipping line 26519: expected 41 fields, saw 48\nSkipping line 28691: expected 41 fields, saw 48\nSkipping line 28918: expected 41 fields, saw 48\nSkipping line 28919: expected 41 fields, saw 48\nSkipping line 29419: expected 41 fields, saw 48\nSkipping line 29422: expected 41 fields, saw 48\nSkipping line 30742: expected 41 fields, saw 48\nSkipping line 30823: expected 41 fields, saw 48\nSkipping line 30824: expected 41 fields, saw 48\nSkipping line 31212: expected 41 fields, saw 48\nSkipping line 32125: expected 41 fields, saw 48\nSkipping line 32140: expected 41 fields, saw 48\nSkipping line 32151: expected 41 fields, saw 48\nSkipping line 32637: expected 41 fields, saw 48\nSkipping line 32714: expected 41 fields, saw 48\nSkipping line 32755: expected 41 fields, saw 48\n'
# 2               NaN           Tx1324324538                 Harry
# 3               NaN                    NaN                   NaN
# 4               NaN             Tx26476112        Scouse-African
# ..              ...                    ...                   ...
# 95              NaN  Tx1263426507881545728              UMXHOSA🖤
# 96              NaN   Tx724355250723930112  [indistinct chatter]
# 97              NaN           Tx1133505523              S'boniso
# 98              NaN   Tx801858130623758336   Lucas van Vuuren ⚓️
# 99              NaN            Tx217439647                  ZG²⁴
#
#      authorHandle  authorHandleId  \
# 0   WestoverAllan    1.190593e+18
# 1      LKMamabolo    3.299075e+09
# 2    HarrisMolefi    1.324325e+09
# 3             NaN             NaN
# 4      me_shell33    2.647611e+07
# ..            ...             ...
# 95  taka_mabhabha    1.263427e+18
# 96      waminkosi    7.243553e+17
# 97     Bruno_Mzeh    1.133506e+09
# 98  lucascvvuuren    8.018581e+17
# 99       zvineigw    2.174396e+08
#
#                                     authorPictureLink  \
# 0   https://piccache.brandseye.com/api/https%3A%2F...
# 1   https://piccache.brandseye.com/api/https%3A%2F...
# 2   https://piccache.brandseye.com/api/https%3A%2F...
# 3                                                 NaN
# 4   https://piccache.brandseye.com/api/https%3A%2F...
# ..                                                ...
# 95  https://piccache.brandseye.com/api/https%3A%2F...
# 96  https://piccache.brandseye.com/api/https%3A%2F...
# 97  https://piccache.brandseye.com/api/https%3A%2F...
# 98  https://piccache.brandseye.com/api/https%3A%2F...
# 99  https://piccache.brandseye.com/api/https%3A%2F...
#
#                     authorProfileLink  \
# 0   https://twitter.com/WestoverAllan
# 1      https://twitter.com/LKMamabolo
# 2    https://twitter.com/HarrisMolefi
# 3                                 NaN
# 4      https://twitter.com/me_shell33
# ..                                ...
# 95  https://twitter.com/taka_mabhabha
# 96      https://twitter.com/waminkosi
# 97     https://twitter.com/Bruno_Mzeh
# 98  https://twitter.com/lucascvvuuren
# 99       https://twitter.com/zvineigw
#
#                                             authorBio  \
# 0             husband father sports lover love travel
# 1                              👨🏾‍🦲I’m an African 🌍🇿🇦
# 2   Agricultural Economics & Risk Management gradu...
# 3                                                 NaN
# 4   nutjob | \ndemotivational speaker | \nsouth af...
# ..                                                ...
# 95  IG:http://instagram.com/asekho.nonketa○ uMxhos...
# 96                             part of the experiment
# 97                                          🇿🇦Mnguni🐂
# 98  Studying MBChB V at the University of Pretoria...
# 99  ERP | SQL | I.T. Practitioner | Arsenal FC | d...
#
#                 authorLocation  authorTimezone  \
# 0                          NaN             NaN
# 1                 South Africa             NaN
# 2    North West,Potchefstroom              NaN
# 3                          NaN             NaN
# 4                          NaN             NaN
# ..                         ...             ...
# 95                         NaN             NaN
# 96                         NaN             NaN
# 97  Johannesburg, South Africa             NaN
# 98                South Africa             NaN
# 99                      JHB SA             NaN
#
#                                          replyToUri       replyToId  \
# 0   http://twitter.com/x/status/1267051787556728832  150335-1738334
# 1   http://twitter.com/x/status/1267120907761352705             NaN
# 2                                               NaN             NaN
# 3                                               NaN             NaN
# 4                                               NaN             NaN
# ..                                              ...             ...
# 95                                              NaN             NaN
# 96                                              NaN             NaN
# 97                                              NaN             NaN
# 98  http://twitter.com/x/status/1267051787556728832  150335-1738334
# 99  http://twitter.com/x/status/1267051787556728832  150335-1738334
#
#                                        reshareOfUri     reshareOfId  \
# 0                                               NaN             NaN
# 1                                               NaN             NaN
# 2   http://twitter.com/x/status/1267051787556728832  150335-1738334
# 3   http://twitter.com/x/status/1267051787556728832  150335-1738334
# 4   http://twitter.com/x/status/1267051787556728832  150335-1738334
# ..                                              ...             ...
# 95  http://twitter.com/x/status/1266962804906561542             NaN
# 96  http://twitter.com/x/status/1267051787556728832  150335-1738334
# 97  http://twitter.com/x/status/1267051787556728832  150335-1738334
# 98                                              NaN             NaN
# 99                                              NaN             NaN
#
#             toId              toName        toHandle    toHandleId  \
# 0    Tx895245463      Karin Richards  Richards_Karin  8.952455e+08
# 1   Tx2335903797      Doctor🔥🇿🇼🇿🇦🇳🇬💉    master_nzama  2.335904e+09
# 2    Tx895245463      Karin Richards  Richards_Karin  8.952455e+08
# 3            NaN                 NaN             NaN           NaN
# 4    Tx895245463      Karin Richards  Richards_Karin  8.952455e+08
# ..           ...                 ...             ...           ...
# 95  Tx2453406484  Uxamu ongavinjelwa    Alex_Lwandle  2.453406e+09
# 96   Tx895245463      Karin Richards  Richards_Karin  8.952455e+08
# 97   Tx895245463      Karin Richards  Richards_Karin  8.952455e+08
# 98   Tx895245463      Karin Richards  Richards_Karin  8.952455e+08
# 99   Tx895245463      Karin Richards  Richards_Karin  8.952455e+08
#
#                                           postExtract   relevancy  \
# 0   Absa expects South Africa's real GDP to fall b...    RELEVANT
# 1                                                 NaN    RELEVANT
# 2                                                 NaN    RELEVANT
# 3                                                 NaN  IRRELEVANT
# 4                                                 NaN    RELEVANT
# ..                                                ...         ...
# 95                                                NaN    RELEVANT
# 96                                                NaN    RELEVANT
# 97                                                NaN    RELEVANT
# 98  Absa expects South Africa's real GDP to fall b...    RELEVANT
# 99  Absa expects South Africa's real GDP to fall b...    RELEVANT
#
#    relevancyVerified  sentiment sentimentVerified  crowdVerified  \
# 0               True          0              True           True
# 1                NaN         -1               NaN          False
# 2               True          0              True           True
# 3                NaN          0               NaN           True
# 4               True          0              True           True
# ..               ...        ...               ...            ...
# 95               NaN          0               NaN          False
# 96              True          0              True           True
# 97              True          0              True           True
# 98              True          0              True           True
# 99              True          0              True           True
#
#                pickedUp      city.name region.name  country.name  \
# 0   2020-05-31 23:55:34            NaN         NaN           NaN
# 1   2020-05-31 23:53:34            NaN         NaN  South Africa
# 2   2020-05-31 23:51:09  Potchefstroom  North-West  South Africa
# 3   2020-05-31 23:47:40   Johannesburg     Gauteng  South Africa
# 4   2020-05-31 23:42:15            NaN         NaN           NaN
# ..                  ...            ...         ...           ...
# 95  2020-05-31 20:53:57            NaN         NaN           NaN
# 96  2020-05-31 20:52:51            NaN         NaN           NaN
# 97  2020-05-31 20:51:41   Johannesburg     Gauteng  South Africa
# 98  2020-05-31 20:51:04            NaN         NaN  South Africa
# 99  2020-05-31 20:50:26   Johannesburg     Gauteng  South Africa
#
#    language.name category.label gender.label  race.label  engagement     OTS  \
# 0        English       Consumer         Male         NaN         NaN     7.0
# 1            NaN       Consumer          NaN         NaN         NaN  1751.0
# 2        English       Consumer         Male         NaN         NaN   363.0
# 3        English       Consumer          NaN         NaN         NaN     NaN
# 4        English       Consumer          NaN         NaN         NaN   396.0
# ..           ...            ...          ...         ...         ...     ...
# 95       English       Consumer          NaN         NaN         NaN   279.0
# 96       English       Consumer          NaN         NaN         NaN   503.0
# 97       English       Consumer         Male         NaN         NaN   497.0
# 98       English       Consumer         Male         NaN         NaN   340.0
# 99       English       Consumer          NaN         NaN         NaN   180.0
#
#                                                  tags
# 0   segment:Non-CX post tag:Twitter tag:Overall co...
# 1   tag:Engage - received tag:Engage - ticketed ta...
# 2   crowd:duplicate segment:Non-conduct reshare ta...
# 3   crowd:duplicate segment:Non-conduct reshare ta...
# 4   crowd:duplicate segment:Non-conduct reshare ta...
# ..                                                ...
# 95  tag:Absa Premiership tag:Premiership – not Cro...
# 96  crowd:duplicate segment:Non-conduct reshare ta...
# 97  crowd:duplicate segment:Non-conduct reshare ta...
# 98  segment:Non-CX post segment:COVID-19 tag:Twitt...
# 99  crowd:neutral filter segment:Non-CX post tag:T...
#
# [100 rows x 41 columns]

# %%
data
# Out:
#                    id                                            extract  \
# 0      150335-1738949                                            Scary !
# 1      150335-1738890                   @master_nzama @AbsaSouthAfrica 😡
# 2      150335-1738889  RT @Richards_Karin: Absa expects South Africa'...
# 3      150335-1738888                    (this mention has been deleted)
# 4      150335-1738948  RT @Richards_Karin: Absa expects South Africa'...
# ...               ...                                                ...
# 66259  150335-1554305  @tysonbmhlongo @kabelodick @AdvoBarryRoux @FNB...
# 66260  150335-1554304                       @JasonNoah_ Absa\n9357602960
# 66261  150335-1554217  RT @SuperiorZulu: The PIC which is State Owned...
# 66262  150335-1554216  RT @SuperiorZulu: The PIC which is State Owned...
# 66263  150335-1554213  Do you have a luno wallet, ABSA/STANDARD ACCOU...
#
#        sentiment
# 0              0
# 1             -1
# 2              0
# 3              0
# 4              0
# ...          ...
# 66259         -1
# 66260          0
# 66261          0
# 66262          0
# 66263          0
#
# [66264 rows x 3 columns]

# %%
# removes pattern in the input text
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for word in r:
        input_txt = re.sub(word, "", input_txt)
    return input_txt
data.head()
# Out:
#                id                                            extract  \
# 0  150335-1738949                                            Scary !
# 1  150335-1738890                   @master_nzama @AbsaSouthAfrica 😡
# 2  150335-1738889  RT @Richards_Karin: Absa expects South Africa'...
# 3  150335-1738888                    (this mention has been deleted)
# 4  150335-1738948  RT @Richards_Karin: Absa expects South Africa'...
#
#    sentiment
# 0          0
# 1         -1
# 2          0
# 3          0
# 4          0

# %%
# remove twitter handles (@user)
data['clean_tweet'] = np.vectorize(remove_pattern)(data['extract'], "@[\w]*")
data.head()
# Out:
#                id                                            extract  \
# 0  150335-1738949                                            Scary !
# 1  150335-1738890                   @master_nzama @AbsaSouthAfrica 😡
# 2  150335-1738889  RT @Richards_Karin: Absa expects South Africa'...
# 3  150335-1738888                    (this mention has been deleted)
# 4  150335-1738948  RT @Richards_Karin: Absa expects South Africa'...
#
#    sentiment                                        clean_tweet
# 0          0                                            Scary !
# 1         -1                                                  😡
# 2          0  RT : Absa expects South Africa's real GDP to f...
# 3          0                    (this mention has been deleted)
# 4          0  RT : Absa expects South Africa's real GDP to f...

# %%
# remove special characters, numbers and punctuations
data['clean_tweet'] = data['clean_tweet'].str.replace("[^a-zA-Z#]", " ")
data.head()
# Out:
#                id                                            extract  \
# 0  150335-1738949                                            Scary !
# 1  150335-1738890                   @master_nzama @AbsaSouthAfrica 😡
# 2  150335-1738889  RT @Richards_Karin: Absa expects South Africa'...
# 3  150335-1738888                    (this mention has been deleted)
# 4  150335-1738948  RT @Richards_Karin: Absa expects South Africa'...
#
#    sentiment                                        clean_tweet
# 0          0                                            Scary
# 1         -1
# 2          0  RT   Absa expects South Africa s real GDP to f...
# 3          0                     this mention has been deleted
# 4          0  RT   Absa expects South Africa s real GDP to f...

# %%
# remove short words
data['clean_tweet'] = data['clean_tweet'].apply(lambda x: " ".join([w for w in x.split() if len(w)>3]))
data.head()
# Out:
#                id                                            extract  \
# 0  150335-1738949                                            Scary !
# 1  150335-1738890                   @master_nzama @AbsaSouthAfrica 😡
# 2  150335-1738889  RT @Richards_Karin: Absa expects South Africa'...
# 3  150335-1738888                    (this mention has been deleted)
# 4  150335-1738948  RT @Richards_Karin: Absa expects South Africa'...
#
#    sentiment                                        clean_tweet
# 0          0                                              Scary
# 1         -1
# 2          0  Absa expects South Africa real fall Nine point...
# 3          0                          this mention been deleted
# 4          0  Absa expects South Africa real fall Nine point...

# %%
# individual words considered as tokens
tokenized_tweet = data['clean_tweet'].apply(lambda x: x.split())
tokenized_tweet.head()
# Out:
# 0                                              [Scary]
# 1                                                   []
# 2    [Absa, expects, South, Africa, real, fall, Nin...
# 3                       [this, mention, been, deleted]
# 4    [Absa, expects, South, Africa, real, fall, Nin...
# Name: clean_tweet, dtype: object

# %%
# !pip3 install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\refentse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (1.8.1)
# Requirement already satisfied: pillow in c:\users\refentse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from wordcloud) (8.3.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\refentse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from wordcloud) (1.21.2)
# Requirement already satisfied: matplotlib in c:\users\refentse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\refentse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\refentse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\refentse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\refentse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib->wordcloud) (2.4.7)
# Requirement already satisfied: six in c:\users\refentse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# WARNING: You are using pip version 21.1.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Users\Refentse\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
# visualize the frequent words
all_words = " ".join([sentence for sentence in data['clean_tweet']])

from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=42, max_font_size=100).generate(all_words)

# plot the graph
plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
data[data['sentiment'] == 1].count()
# Out:
# id             4750
# extract        4750
# sentiment      4750
# clean_tweet    4750
# dtype: int64

# %%
# frequent words visualization for +ve
all_words = " ".join([sentence for sentence in data['clean_tweet'][data['sentiment']==1]])

wordcloud = WordCloud(width=800, height=500, random_state=42, max_font_size=100).generate(all_words)

# plot the graph
plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
data[data['sentiment'] == 0].count()
# Out:
# id             49132
# extract        49132
# sentiment      49132
# clean_tweet    49132
# dtype: int64

# %%
# frequent words visualization for neutral
all_words = " ".join([sentence for sentence in data['clean_tweet'][data['sentiment']==0]])

wordcloud = WordCloud(width=800, height=500, random_state=42, max_font_size=100).generate(all_words)

# plot the graph
plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
data[data['sentiment'] == -1].count()
# Out:
# id             12382
# extract        12382
# sentiment      12382
# clean_tweet    12382
# dtype: int64

# %%
# frequent words visualization for -ve
all_words = " ".join([sentence for sentence in data['clean_tweet'][data['sentiment']==-1]])

wordcloud = WordCloud(width=800, height=500, random_state=42, max_font_size=100).generate(all_words)

# plot the graph
plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# extract the hashtag
def hashtag_extract(tweets):
    hashtags = []
    # loop words in the tweet
    for tweet in tweets:
        ht = re.findall(r"#(\w+)", tweet)
        hashtags.append(ht)
    return hashtags

# %%
# extract hashtags from non-racist/sexist tweets
ht_positive = hashtag_extract(data['clean_tweet'][data['sentiment']==0])

# extract hashtags from racist/sexist tweets
ht_negative = hashtag_extract(data['clean_tweet'][data['sentiment']==-1])

# extract hashtags from neutral tweets
ht_neutral = hashtag_extract(data['clean_tweet'][data['sentiment']==1])

# %%
# unnest list
ht_positive = sum(ht_positive, [])
ht_negative = sum(ht_negative, [])
ht_neutral = sum(ht_neutral, [])

# %%
ht_positive[:5]
# Out:
# ['agotamiento', 'trabajarencaso', 'vivamejor', 'cambiatuvida', 'robertoaceves']

# %%
freq = nltk.FreqDist(ht_positive)
d = pd.DataFrame({'Word': list(freq.keys()),
                 'Count': list(freq.values())})
d.head(100)
# Out:
#                     Word  Count
# 0            agotamiento      1
# 1         trabajarencaso      1
# 2              vivamejor      1
# 3           cambiatuvida      2
# 4          robertoaceves      1
# ..                   ...    ...
# 95               katlego      4
# 96                tebogo     10
# 97                 mbali      6
# 98  southafricanboerboel      1
# 99   southafricantourism      1
#
# [100 rows x 2 columns]

# %%
# select top 10 hashtags
d = d.nlargest(columns='Count', n=10)
plt.figure(figsize=(15,9))
sns.barplot(data=d, x='Word', y='Count')
plt.show()

# %%
freq = nltk.FreqDist(ht_negative)
d = pd.DataFrame({'Word': list(freq.keys()),
                 'Count': list(freq.values())})
d.head(100)
# Out:
#                         Word  Count
# 0      PutSouthAfricansFirst      4
# 1                       Absa     21
# 2                   Barclays      2
# 3   PutSouthAfricansFirstNow      1
# 4   DontbankwithAbsadontbank      7
# ..                       ...    ...
# 95                       day     10
# 96               coronavirus      3
# 97                  ABSAbank      1
# 98                badservice      2
# 99                 Clickongh      2
#
# [100 rows x 2 columns]

# %%
# select top 10 hashtags
d = d.nlargest(columns='Count', n=10)
plt.figure(figsize=(15,9))
sns.barplot(data=d, x='Word', y='Count')
plt.show()

# %%
# feature extraction
from sklearn.feature_extraction.text import CountVectorizer
bow_vectorizer = CountVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')
bow = bow_vectorizer.fit_transform(data['clean_tweet'])

# %%
# bow[0].toarray()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(bow, data['sentiment'], random_state=42, test_size=0.25)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import f1_score, accuracy_score
from sklearn.metrics import plot_confusion_matrix

# %%
# training
model = MultinomialNB()
model.fit(x_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# testing
pred = model.predict(x_test)
f1_score(y_test, pred, average = None)
# Out:
# array([0.58680406, 0.83655326, 0.42706439])

# %%
accuracy_score(y_test,pred)
# Out:
# 0.7499094530967041

# %%
# use probability to get output
pred_prob = model.predict_proba(x_test)
pred = pred_prob[:, -1] >= 0.3
pred = pred.astype(np.int)

f1_score(y_test, pred, average =None)
# Out:
# array([0.        , 0.83651236, 0.42048346])

# %%
accuracy_score(y_test,pred)
# Out:
# 0.7189424121695038

# %%
plot_confusion_matrix(model, x_test, y_test)
